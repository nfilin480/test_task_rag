# %%
import nest_asyncio
nest_asyncio.apply()  # This allows running async code in Jupyter

from tqdm import tqdm
import pandas as pd
import requests
import json
import re
import asyncio
import aiohttp
from typing import List, Dict, Tuple

# Base prompt remains the same
prompt = ''' You are an expert in natural language processing and query classification. Your task is to label each given query as either "retrieval needed" (1) or "retrieval not needed" (0). 

Instructions:
1. Analyze the query carefully.
2. If the query requires specific, detailed, or specialized external information (e.g., fact-checking, detailed data, or precise terminology), label it as "1" (retrieval needed).
3. If the query is generic, abstract, or related to tasks like summarization, paraphrasing, or general knowledge that can be answered by a language model without external data, label it as "0" (retrieval not needed).
4. Provide your answer in the following format: 
   <label><0 or 1></label>
   <explanation><one or two sentences explaining your reasoning></explanation>

Examples:
Query: When did Virgin Australia start operating?
<label>1</label>
<explanation>This query asks for a specific historical fact (a start date) that is unlikely to be deduced purely from context and requires external factual data.</explanation>

Query: Which is a species of fish? Tope or Rope
<label>1</label>
<explanation>The query requires knowing the correct fish species between two options, which is a precise factual lookup rather than a generic or inferable answer.</explanation>

Query: Alice's parents have three daughters: Amy, Jessy, and what’s the name of the third daughter?
<label>0</label>
<explanation>This is a riddle where the answer is directly given in the query ("Alice"), making external retrieval unnecessary.</explanation>

Query: What individual has won the most Olympic gold medals in the history of the games?
<label>1</label>
<explanation>This is a specific fact-based question that requires up-to-date and precise information about Olympic records, which typically necessitates an external data source.</explanation>

Query: Which Dutch artist painted “Girl with a Pearl Earring”?
<label>0</label>
<explanation>This is a well-known art fact that most language models can answer from general knowledge without needing to retrieve external information.</explanation>
   
Now, please label the following query:

{query}
'''

async def process_query_batch(session: aiohttp.ClientSession, queries: List[str], 
                            semaphore: asyncio.Semaphore) -> List[Tuple[int, float, str]]:
    async def process_single_query(query: str) -> Tuple[int, float, str]:
        async with semaphore:
            try:
                payload = {
                    "model": "deepseek-r1:14b",
                    "prompt": prompt.format(query=query),
                    "stream": False,
                    'num_predict': 30,
                    "temperature": 0.1
                }
                
                async with session.post('http://localhost:11435/api/generate', 
                                      json=payload) as response:
                    result = await response.json()
                    response_text = result['response']
                    #print(response_text)

                    think = re.search(r'<think>(.*?)</think>', response_text)
                    think = think.group(1).strip() if think else ""
                    #print(think)
                    
                    label_match = re.search(r'<label>(\d)</label>', response_text)
                    explanation_match = re.search(r'<explanation>(.*?)</explanation>', response_text)
                    
                    label = int(label_match.group(1)) if label_match else -1
                    explanation = explanation_match.group(1).strip() if explanation_match else ""
                    confidence = 1.0 if label != -1 else 0.0
                    
                    return label, confidence, explanation, think
            except Exception as e:
                print(f"Error processing query: {e}")
                return -1, 0.0, "", ""

    tasks = [process_single_query(query) for query in queries]
    return await asyncio.gather(*tasks)

async def evaluate_model(df: pd.DataFrame, batch_size: int = 8) -> pd.DataFrame:
    queries = [f"{i} {c}" for i, c in zip(df['rewrite_prompt'].astype(str), 
                                         df['original_text'].astype(str))]
    results = []
    
    semaphore = asyncio.Semaphore(4)
    
    async with aiohttp.ClientSession() as session:
        for i in tqdm(range(0, len(queries), batch_size)):
            batch_queries = queries[i:i + batch_size]
            batch_results = await process_query_batch(session, batch_queries, semaphore)
            
            for j, (pred_label, confidence, reasoning, think) in enumerate(batch_results):
                idx = i + j
                results.append({
                    'query': queries[idx],
                    'instruction': df.iloc[idx]['rewrite_prompt'],
                    'context': df.iloc[idx]['original_text'],
                    'predicted_label': pred_label,
                    'confidence': confidence,
                    'reasoning': reasoning,
                    'think': think
                })
            
            if i % 100 == 0:
                pd.DataFrame(results).to_csv(f'ollama_results_{i}.csv', index=False)
    
    return pd.DataFrame(results)

# %%
from datasets import load_dataset
import pandas as pd
data = load_dataset("positivethoughts/merge_rewrite_13.3k")
df = pd.DataFrame(data['train'])
df
# Out:
#                                           rewrite_prompt  \
# 0              Paraphrase the provided text effectively.
# 1      Rewrite the text in a more informal tone while...
# 2      Rearrange the sentence structure for a fresh p...
# 3      Shift the focus to Rachel's perspective withou...
# 4      Adapt the text for a workplace setting while m...
# ...                                                  ...
# 13360  1950s American Suburbia: Recast the essay with...
# 13361  Write like William Shakespeare: Write in Shake...
# 13362  Write like a Beat poet: Use the rhythmic and r...
# 13363  Space Explorer: Adopt the curious and hopeful ...
# 13364  Write like J.K. Rowling: Craft the text in the...
#
#                                           rewritten_text  \
# 0      A batch of cookies were made by Amanda and she...
# 1      Olivia and Olivier are both backing the libera...
# 2      To get more stuff done, Kim may consider tryin...
# 3      Rachel stands outside Edward's door, feeling a...
# 4      Samantha is feeling uncertain at work after ov...
# ...                                                  ...
# 13360  The picket fences and shining chrome of 1950s ...
# 13361  Fair maiden, thy beauty doth beguile,\nWith ey...
# 13362  Candle, light in the darkness, life in the bel...
# 13363  **Cooper's Journey**\n\nIn the vast expanse of...
# 13364  In the heart of a bustling street, where tower...
#
#                                            original_text          id
# 0      Amanda baked cookies and will bring Jerry some...        None
# 1      Olivia and Olivier are voting for liberals in ...        None
# 2      Kim may try the pomodoro technique recommended...        None
# 3      Edward thinks he is in love with Bella. Rachel...        None
# 4      Sam is confused, because he overheard Rick com...        None
# ...                                                  ...         ...
# 13360  `` Nein, Nein, Die Englisch sind hier! Geoff i...  dZpCXooaHn
# 13361  Trigger warning. \n \n \n -- - \n \n \n Every ...  FWONqGJidk
# 13362  Nobody understand candle. Candle is light, can...  TDCNripkkT
# 13363  **Cooper is back! ** \n \n Last year they left...  xulqOrwbms
# 13364  Rowan collapsed on the steps of the church in ...  pEtQCTsZUf
#
# [13365 rows x 4 columns]

# %%
# Load and prepare data
#df = pd.read_csv('./code_alpaca.csv')
df['total_chars'] = df['rewrite_prompt'].fillna('').str.len() + df['original_text'].fillna('').str.len()
df = df[df['total_chars'] <= 2000]  # Filter long sequences
df = df[:3000]

# Run evaluation
loop = asyncio.get_event_loop()
results_df = loop.run_until_complete(evaluate_model(df, batch_size=8))

# Save results
results_df.to_csv('ollama_results_final.csv', index=False)

# Print statistics
print("\nLabel distribution:")
print(results_df['predicted_label'].value_counts())
# Out:
#  75%|███████▌  | 282/375 [3:17:53<42:30, 27.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 # Run evaluation
#       8 loop = asyncio.get_event_loop()
# ----> 9 results_df = loop.run_until_complete(evaluate_model(df, batch_size=8))
#      11 # Save results
#      12 results_df.to_csv('ollama_results_final.csv', index=False)
#
# File ~/miniconda3/envs/ai/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/miniconda3/envs/ai/lib/python3.10/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File ~/miniconda3/envs/ai/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
#  77%|███████▋  | 287/375 [3:20:35<43:57, 29.97s/it]

# %%
import pandas as pd
results_df = pd.read_csv('./ollama_results_2200.csv')
results_df['predicted_label'].value_counts()
# Out:
# predicted_label
#  0    2059
#  1     134
# -1      15
# Name: count, dtype: int64

# %%
results_df[results_df['predicted_label'] == 1]
# Out:
#                                                   query  \
# 111   Shift the focus to highlight the characters' r...
# 330   Provide an updated status change for Pedro. Pe...
# 354   Provide a recommendation for a romantic movie....
# 462   "Provide advice on optimizing battery usage fo...
# 593   Reverse the order of sentences. Tom wants to b...
# ...                                                 ...
# 2157  Explain this as if it were a sports commentary...
# 2170  Rewrite this as a project to be developed. The...
# 2177  Imagine this as an insight to be discovered. P...
# 2180  Write the text as if it were a late-night come...
# 2202  Imagine this as an accounting software's AI be...
#
#                                             instruction  \
# 111   Shift the focus to highlight the characters' r...
# 330         Provide an updated status change for Pedro.
# 354      Provide a recommendation for a romantic movie.
# 462   "Provide advice on optimizing battery usage fo...
# 593                     Reverse the order of sentences.
# ...                                                 ...
# 2157    Explain this as if it were a sports commentary.
# 2170         Rewrite this as a project to be developed.
# 2177       Imagine this as an insight to be discovered.
# 2180  Write the text as if it were a late-night come...
# 2202  Imagine this as an accounting software's AI be...
#
#                                                 context  predicted_label  \
# 111   Joe, Tim and Jack are watching 'The Millionaire'.                1
# 330                                Pedro got promoted.                 1
# 354          Emma recommends Mario "I'm in love" movie.                1
# 462            Waze is consuming batteries really fast.                1
# 593   Tom wants to borrow Alan's car but Alan needs ...                1
# ...                                                 ...              ...
# 2157  Stack traces in GHCJS June 20, 2014 - Tagged a...                1
# 2170  There's been some level of uncertainty regardi...                1
# 2177  Passing the sanctions bill is likely to be a r...                1
# 2180  Google-centric Chromebooks are turning out to ...                1
# 2202  A majority of Michigan voters in a new poll wo...                1
#
#       confidence                                          reasoning  think
# 111          1.0  This query asks for specific and detailed info...    NaN
# 330          1.0  This query requests specific and personalized ...    NaN
# 354          1.0  The query refers to a specific romantic movie ...    NaN
# 462          1.0  The query asks for specific advice on optimizi...    NaN
# 593          1.0  This query asks for the reversal of sentence o...    NaN
# ...          ...                                                ...    ...
# 2157         1.0  The query asks for an explanation of stack tra...    NaN
# 2170         1.0  This query involves a detailed analysis of a s...    NaN
# 2177         1.0  The query pertains to a detailed and current l...    NaN
# 2180         1.0  This query provides specific data about Chrome...    NaN
# 2202         1.0  This query includes specific polling data (per...    NaN
#
# [134 rows x 7 columns]
